# %%
import pandas as pd
csv_file_path = '/content/drive/MyDrive/LLM-T2/DATASETS/SVAMP/data/cv_asdiv-a/fold0/train.csv'


# --- Load and Display CSV Data ---

# Loading a CSV is very direct with pandas
df = pd.read_csv(csv_file_path)

print(f"--- Dataset ({csv_file_path}) ---")

# Display the first 5 rows
print("\nFirst 5 rows (head):")
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 80) # Truncate long text
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-991150521.py in <cell line: 0>()
#      11
#      12 # Loading a CSV is very direct with pandas
# ---> 13 df = pd.read_csv(csv_file_path)
#      14
#      15 print(f"--- Dataset ({csv_file_path}) ---")
#
# ...

# %%
# Display columns and their types
print("\nColumns and Data Types (info):")
df.info()
